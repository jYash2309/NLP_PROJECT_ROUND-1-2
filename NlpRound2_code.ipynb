# %%
import urllib.request 
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import nltk
nltk.download('omw-1.4')
import re
import inflect
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS
from collections import Counter

nltk.download('wordnet')
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
def open_url(url):
    file = urllib.request.urlopen(url)
    decoded_line = ''
    for line in file:
	    decoded_line += line.decode("utf-8")
    return decoded_line
def discard(text):
    # removing starting and ending portion that is unwanted
    start = text.find('*** START OF THE PROJECT')
    end = text.find('*** END OF THE PROJECT')
    text = text[start:end]
    # removing links from text
    re.sub(r'http\S+', '', text)
    return text
def lower_case(text: str):
    return text.lower()
def lemmanization(text):
    arr = text.split()
    array = []
    lemmatizer = WordNetLemmatizer()
    for i in arr:
        array.append(lemmatizer.lemmatize(i))
    return ' '.join(array)
def remove_tags(text):
    TAG_RE = re.compile(r'<[^>]+>')
    return TAG_RE.sub('', text)
def remove_punctuations(text):
    punc = '''!()-[]{};:'"\,<>./?’@”#$%^“&*_~'''
    for ele in text:
        if ele in punc:
            text = text.replace(ele, "")
    return text
def tokenization(text):
    return nltk.word_tokenize(text)
def stemming(text):
    tokens=tokenization(text)
    arr = []
    ps = PorterStemmer()
    for i in tokens:
        arr.append(ps.stem(i))
    return ' '.join(arr)
def remove_stop_words(text):
    # return [word for word in tokens if word not in STOPWORDS]
    tokens=tokenization(text)
    arr = []
    stop_words = set(stopwords.words('english'))
    for i in tokens:
        if i not in stop_words:
            arr.append(i)
    return ' '.join(arr)
def frequency_distribution(text):
    tokens = word_tokenize(text) 
    pd.Series(tokens).value_counts()[:20].plot(kind='bar')
def word_cloud_plot(text):
    tokens = tokenization(text)
    wordcloud = WordCloud(width=1600, height=800, max_font_size=200, background_color="black").generate(text)
    # plt the image generated by WordCloud class
    plt.figure(figsize=(12,10))
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.show()
def word_length_frequency(text):
    token = tokenization(text)
    dic = list(set(token))
    length = [len(i) for i in token]
    pd.Series(length).value_counts()[:20].plot(kind='bar')
def frequency_distribution_of_tags(tags):
    tags = [i[1] for i in tags]
    count = Counter(tags)
    x = [i for i in count]
    y = [count[i] for i in count]
    plt.plot(x, y)
    plt.show()
def pos_tagging(text):
    tokens = tokenization(text)
    tag = nltk.pos_tag(tokens)
    return tag

# %%
 text1 = open(r"/content/drive/MyDrive/NLP/nlpbook .txt",encoding='utf-8').read()

def preprocessing(text):
    text=discard(text)
    text=lower_case(text)
    text=remove_tags(text)
    text=lemmanization(text)
    text=remove_punctuations(text)
    text=stemming(text)
    return text
# print(text1)
text1 = preprocessing(text1)
text1 = remove_stop_words(text1)
print(text1)
# Out:
# start project gutenberg ebook war world cover war world h g well ‘ shall dwell world inhabit lord world thing made man kepler quot anatomi melancholi content book one—th come martian eve war ii fall star iii horsel common iv cylind open v heatray vi heatray chobham road vii reach home viii friday night ix fight begin x storm xi window xii saw destruct weybridg shepperton xiii fell curat xiv london xv happen surrey xvi exodu london xvii thunder child book two—th earth martian foot ii saw ruin hous iii day imprison iv death curat v still vi work fifteen day vii man putney hill viii dead london ix wreckag x epilogu book one come martian eve war one would believ last year nineteenth centuri thi world wa watch keenli close intellig greater man yet mortal hi men busi themselv variou concern scrutinis studi perhap almost narrowli man microscop might scrutinis transient creatur swarm multipli drop water infinit complac men went fro thi globe littl affair seren assur empir matter possibl infusoria microscop one gave thought older world space sourc human danger thought onli dismiss idea life upon imposs improb curiou recal mental habit depart day terrestri men fanci might men upon mar perhap inferior themselv readi welcom missionari enterpris yet across gulf space mind mind beast perish intellect vast cool unsympathet regard thi earth enviou eye slowli sure drew plan us earli twentieth centuri came great disillusion planet mar scarc need remind reader revolv sun mean distanc 140000000 mile light heat receiv sun bare half receiv thi world must nebular hypothesi ha ani truth older world long befor thi earth ceas molten life upon surfac must begun cours fact scarc one seventh volum earth must acceler cool temperatur life could begin ha air water necessari support anim exist yet vain man blind hi vaniti writer veri end nineteenth centuri express ani idea intellig life might develop far inde beyond earthli level wa gener understood sinc mar older earth scarc quarter superfici area remot sun necessarili follow onli distant time begin nearer end secular cool must someday overtak planet ha alreadi gone far inde neighbour physic condit still larg mysteri know even equatori region midday temperatur bare approach coldest winter air much attenu ocean shrunk cover third surfac slow season chang huge snowcap gather melt either pole period inund temper zone last stage exhaust u still incred remot ha becom presentday problem inhabit mar immedi pressur necess ha brighten intellect enlarg power harden heart look across space instrument intellig scarc dream see nearest distanc onli 35000000 mile sunward morn star hope warmer planet green veget grey water cloudi atmospher eloqu fertil glimps drift cloud wisp broad stretch popul countri narrow navycrowd sea men creatur inhabit thi earth must least alien lowli monkey lemur us intellectu side man alreadi admit life incess struggl exist would seem thi belief mind upon mar world far gone cool thi world still crowd life crowd onli regard inferior anim carri warfar sunward inde onli escap destruct gener gener creep upon befor judg harshli must rememb ruthless utter destruct speci ha wrought onli upon anim vanish bison dodo upon inferior race tasmanian spite human like entir swept exist war extermin wage european immigr space fifti year apostl merci complain martian war spirit martian seem calcul descent amaz subtlety—their mathemat learn evid far excess ours—and carri prepar wellnigh perfect unanim instrument permit might seen gather troubl far back nineteenth centuri men like schiaparelli watch red planet—it odd bytheby countless centuri mar ha star war—but fail interpret fluctuat appear mark map well time martian must get readi dure opposit 1894 great light wa seen illumin part disk first lick observatori perrotin nice observ english reader heard first issu natur date august 2 inclin think thi blaze may cast huge gun vast pit sunk planet shot fire us peculiar mark yet unexplain seen near site outbreak dure next ...

# %%
def give_noun(tag):
    is_noun = lambda pos: pos[:1] == 'N'
    return [word for (word, pos) in tag if is_noun(pos)]
    
def give_verb(tag):
    is_verb = lambda pos: pos[:1] == 'V'
    return [word for (word, pos) in tag if is_verb(pos)]

tag1 = pos_tagging(text1)

noun_book_1 = give_noun(tag1)
verb_book_1 = give_verb(tag1)

print(len(noun_book_1), noun_book_1)
print(len(verb_book_1), verb_book_1)
# Out:
# 16595 ['start', 'project', 'ebook', 'war', 'world', 'cover', 'war', 'world', 'h', 'g', '‘', 'world', 'inhabit', 'world', 'thing', 'man', 'kepler', 'quot', 'anatomi', 'book', 'eve', 'war', 'ii', 'fall', 'star', 'horsel', 'iv', 'cylind', 'v', 'heatray', 'vi', 'heatray', 'chobham', 'road', 'reach', 'home', 'viii', 'night', 'ix', 'fight', 'x', 'storm', 'xi', 'window', 'xii', 'destruct', 'weybridg', 'shepperton', 'xiii', 'london', 'xv', 'surrey', 'xvi', 'thunder', 'child',
', 'saw', 'garden', 'call', 'made', 'saw', 'said', 'said', 'fallen', 'meteorit', 'someth', 'stood', 'said', 'told', 'seen', 'take', 'spade', 'came', 'hurri', 'found', 'lie', 'bright', 'listen', 'conclud', 'insid', 'insens', 'quit', 'went', 'help', 'run', 'take', 'went', 'mind', 'mar', 'took', 'went', 'get', 'lost', 'go', 'found', 'lay', 'appear', 'embed', 'seem', 'think', 'done', 'gone', 'edg', 'stop', 'began', 'play', 'hang', 'stare', 'ogilvi', 'left', 'expect', 'went', 'came', 'heard', 'rotat', 'got', 'object', 'glanc', 'tree', 'blown', 'grey', 'mean', 'contain', 'thought', 'automat', 'believ', 'mar', 'aris', 'felt', 'seem', 'found', 'appear', 'stori', 'woke', 'exchang', 'observatori', 'woke', 'walk', 'woke', 'consider', 'cloud', 'see', 'give', 'smoke', 'sent', 'go', 'found', 'learn', 'spade', 'give', 'stand', 'wa', 'seem', 'embed', 'edg', 'mind', 'go', 'said', 'especi', 'want', 'put', 'keep', 'told', 'unscrew', 'appear', 'heard', 'repres', 'told', 'expect', 'went', 'set', 'hurri', 'woke', 'stood', 'appear', 'go', 'drew', 'heard', 'keep', 'keep', 'came', 'said', 'ascrewin', 'agoin', 'went', 'think', 'peopl', 'fallen', 'said', 'littl', 'seem', 'say', 'said', 'keep', 'know', 'know', 'woke', 'screw', 'somebodi', 'screw', 'come', 'fell', 'ring', 'stuck', 'head', 'seem', 'think', 'expect', 'see', 'essenti', 'know', 'look', 'someth', 'snake', 'came', 'keep', 'tentacl', 'began', 'saw', 'peopl', 'heard', 'saw', 'edg', 'found', 'run', 'stood', 'caught', 'wet', 'round', 'say', 'saliva', 'pulsat', 'seen', 'strang', 'tentacl', 'strang', 'intens', 'eyes—wer', 'crippl', 'thi', 'glimps', 'fallen', 'give', 'appear', 'turn', 'run', 'made', 'avert', 'pine', 'stop', 'develop', 'stand', 'lay', 'saw', 'fallen', 'got', 'seem', 'slip', 'fanci', 'reach', 'go', 'invis', 'made', 'come', 'woke', 'amaz', 'stand', 'say', 'stood', 'feed', 'come', 'remain', 'dare', 'go', 'felt', 'began', 'walk', 'rose', 'spun', 'go', 'woke', 'approached—h', 'said', 'see', 'said', 'made', 'stood', 'gave', ' ...

# %%
from nltk.corpus import wordnet as wn
def categories_word(words):
    categories = []
    for i in words:
        categorie = []
        for syn in wn.synsets(i):
            if ('noun' in syn.lexname()) & ('Tops' not in syn.lexname()):
                categorie.append(syn.lexname())
            if 'verb' in syn.lexname():
                categorie.append(syn.lexname())
        categories.append(categorie)
    return categories

noun_cat_1 = categories_word(noun_book_1)
verb_cat_1 = categories_word(verb_book_1)
print(verb_cat_1)
# Out:
# [['verb.cognition', 'verb.stative', 'verb.stative', 'verb.stative', 'verb.communication'], ['verb.social', 'verb.change', 'verb.creation', 'verb.communication', 'verb.creation', 'verb.creation', 'verb.cognition', 'verb.creation', 'verb.creation', 'verb.possession', 'verb.creation', 'verb.stative', 'verb.motion', 'verb.stative', 'verb.creation', 'verb.creation', 'verb.creation', 'verb.change', 'verb.body', 'verb.social', 'verb.possession', 'verb.motion', 'verb.cognition', 'verb.social', 'verb.social', 'verb.creation', 'verb.change', 'verb.motion', 'verb.body', 'verb.stative', 'verb.stative', 'verb.stative', 'verb.stative', 'verb.stative', 'verb.perception', 'verb.motion', 'verb.motion', 'verb.creation', 'verb.creation', 'verb.contact', 'verb.communication', 'verb.communication', 'verb.cognition', 'verb.cognition', 'verb.change', 'verb.change', 'verb.change', 'verb.body', 'verb.body'], ['noun.body', 'verb.motion', 'verb.motion', 'verb.change', 'verb.change', 'verb.stative', 'verb.change', 'verb.stative', 'verb.stative', 'verb.stative', 'verb.stative', 'verb.motion', 'verb.stative', 'verb.change', 'verb.stative', 'verb.stative', 'verb.motion', 'verb.cognition', 'verb.stative', 'verb.stative', 'verb.perception', 'verb.cognition'], ['noun.person', 'verb.change', 'verb.stative', 'verb.change', 'verb.communication', 'verb.stative', 'verb.stative', 'verb.stative', 'verb.social', 'verb.social', 'verb.communication'], ['noun.communication', 'noun.artifact', 'noun.artifact', 'verb.contact', 'verb.perception', 'verb.cognition', 'verb.perception', 'verb.creation', 'verb.cognition', 'verb.cognition', 'verb.perception', 'verb.motion', 'verb.communication', 'verb.cognition', 'verb.social', 'verb.social', 'verb.social', 'verb.social', 'verb.contact', 'verb.social', 'verb.perception', 'verb.cognition', 'verb.perception', 'verb.perception', 'verb.perception', 'verb.motion', 'verb.competition', 'verb.cognition'], ['noun.substance', 'noun.artifact', 'noun.act', 'verb.contact', 'verb.motion', 'verb.contact', 'verb.motion', 'verb.motion', 'verb.change', 'verb.stative', 'verb.weather', 'verb.social', 'verb.stative', 'verb.stative', 'verb.possession', 'verb.change', 'verb.change', 'verb.social', 'verb.social', 'verb.possession', 'verb.motion', 'verb.stative', 'verb.social', 'verb.possession', 'verb.possession', 'verb.possession', 'verb.possession', 'verb.motion', 'verb.motion', 'verb.motion', 'verb.contact', 'verb.change', 'verb.change', 'verb.change', 'verb.change', 'verb.change', 'verb.change', 'verb.change'], ['verb.change', 'verb.change', 'verb.social', 'verb.change', 'verb.possession'], [], ['noun.communication', 'noun.artifact', 'noun.artifact', 'verb.contact', 'verb.perception', 'verb.cognition', 'verb.perception', 'verb.creation', 'verb.cognition', 'verb.cognition', 'verb.perception', 'verb.motion', 'verb.communication', 'verb.cognition', 'verb.social', 'verb.social', 'verb.social', 'verb.social', 'verb.contact', 'verb.social', 'verb.perception', 'verb.cognition', 'verb.perception', 'verb.perception', 'verb.perception', 'verb.motion', 'verb.competition', 'verb.cognition'], ['verb.social', 'verb.social'], [], [], [], [], ['verb.motion', 'verb.social', 'verb.motion', 'verb.change', 'verb.stative', 'verb.stative', 'verb.stative', 'verb.change', 'verb.change', 'verb.stative', 'verb.perception', 'verb.contact', 'verb.consumption', 'verb.change', 'verb.stative', 'verb.stative', 'verb.change', 'verb.stative', 'verb.stative', 'verb.motion', 'verb.competition', 'verb.stative', 'verb.stative', 'verb.stative', 'verb.stative', 'verb.stative', 'verb.contact', 'verb.consumption', 'verb.cognition', 'verb.change'], ['noun.location'], [], ['verb.possession', 'verb.possession', 'verb.possession', 'verb.possession', 'verb.communication', 'verb.creation', 'verb.communication', 'verb.possession', 'verb.creation', 'verb.cognition', 'verb.creation', 'verb.possession', 'verb.creation', 'verb.possession', 'verb.social', 'verb.possession', 'verb.possession', 'verb.comm ...

# %%
def synset(noun, verb):
    nouns = []
    verbs = []
    for word in noun:
        for syn in wn.synsets(word):
            if ('noun' in syn.lexname()) & ('Tops' not in syn.lexname()):
                nouns.append(syn.lexname())
            if 'verb' in syn.lexname():
                verbs.append(syn.lexname())
    for word in verb:
        for syn in wn.synsets(word):
            if ('noun' in syn.lexname()) & ('Tops' not in syn.lexname()):
                nouns.append(syn.lexname())
            if 'verb' in syn.lexname():
                verbs.append(syn.lexname())

    return nouns, verbs

noun_superset1, verb_superset1 = synset(noun_book_1, verb_book_1)
print(verb_superset1)
# Out:
# ['verb.change', 'verb.change', 'verb.motion', 'verb.stative', 'verb.creation', 'verb.creation', 'verb.motion', 'verb.motion', 'verb.motion', 'verb.social', 'verb.competition', 'verb.stative', 'verb.social', 'verb.motion', 'verb.communication', 'verb.stative', 'verb.contact', 'verb.perception', 'verb.perception', 'verb.creation', 'verb.creation', 'verb.cognition', 'verb.creation', 'verb.creation', 'verb.contact', 'verb.cognition', 'verb.competition', 'verb.contact', 'verb.contact', 'verb.stative', 'verb.stative', 'verb.communication', 'verb.stative', 'verb.motion', 'verb.communication', 'verb.competition', 'verb.social', 'verb.perception', 'verb.competition', 'verb.communication', 'verb.communication', 'verb.stative', 'verb.social', 'verb.social', 'verb.possession', 'verb.perception', 'verb.contact', 'verb.contact', 'verb.contact', 'verb.competition', 'verb.competition', 'verb.body', 'verb.body', 'verb.competition', 'verb.stative', 'verb.stative', 'verb.stative', 'verb.social', 'verb.competition', 'verb.cognition', 'verb.social', 'verb.social', 'verb.social', 'verb.competition', 'verb.motion', 'verb.motion', 'verb.change', 'verb.stative', 'verb.weather', 'verb.social', 'verb.stative', 'verb.stative', 'verb.possession', 'verb.change', 'verb.change', 'verb.social', 'verb.social', 'verb.possession', 'verb.motion', 'verb.stative', 'verb.social', 'verb.possession', 'verb.possession', 'verb.possession', 'verb.possession', 'verb.motion', 'verb.motion', 'verb.motion', 'verb.contact', 'verb.change', 'verb.change', 'verb.change', 'verb.change', 'verb.change', 'verb.change', 'verb.change', 'verb.stative', 'verb.creation', 'verb.change', 'verb.motion', 'verb.motion', 'verb.contact', 'verb.communication', 'verb.social', 'verb.stative', 'verb.motion', 'verb.possession', 'verb.competition', 'verb.social', 'verb.motion', 'verb.competition', 'verb.competition', 'verb.social', 'verb.social', 'verb.stative', 'verb.contact', 'verb.weather', 'verb.weather', 'verb.competition', 'verb.creation', 'verb.creation', 'verb.motion', 'verb.communication', 'verb.weather', 'verb.communication', 'verb.cognition', 'verb.social', 'verb.social', 'verb.social', 'verb.perception', 'verb.contact', 'verb.possession', 'verb.motion', 'verb.cognition', 'verb.social', 'verb.social', 'verb.social', 'verb.contact', 'verb.creation', 'verb.body', 'verb.motion', 'verb.social', 'verb.social', 'verb.motion', 'verb.creation', 'verb.social', 'verb.creation', 'verb.stative', 'verb.social', 'verb.social', 'verb.social', 'verb.perception', 'verb.emotion', 'verb.creation', 'verb.contact', 'verb.contact', 'verb.consumption', 'verb.cognition', 'verb.change', 'verb.change', 'verb.change', 'verb.social', 'verb.competition', 'verb.cognition', 'verb.social', 'verb.social', 'verb.social', 'verb.motion', 'verb.motion', 'verb.change', 'verb.change', 'verb.stative', 'verb.change', 'verb.stative', 'verb.stative', 'verb.stative', 'verb.stative', 'verb.motion', 'verb.stative', 'verb.change', 'verb.stative', 'verb.stative', 'verb.motion', 'verb.cognition', 'verb.stative', 'verb.stative', 'verb.perception', 'verb.cognition', 'verb.competition', 'verb.perception', 'verb.social', 'verb.perception', 'verb.perception', 'verb.perception', 'verb.perception', 'verb.communication', 'verb.social', 'verb.competition', 'verb.stative', 'verb.stative', 'verb.social', 'verb.competition', 'verb.stative', 'verb.motion', 'verb.motion', 'verb.motion', 'verb.change', 'verb.motion', 'verb.social', 'verb.communication', 'verb.change', 'verb.contact', 'verb.contact', 'verb.competition', 'verb.possession', 'verb.change', 'verb.stative', 'verb.social', 'verb.contact', 'verb.contact', 'verb.consumption', 'verb.cognition', 'verb.cognition', 'verb.change', 'verb.change', 'verb.body', 'verb.body', 'verb.change', 'verb.possession', 'verb.body', 'verb.change', 'verb.stative', 'verb.motion', 'verb.body', 'verb.change', 'verb.body', 'verb.motion', 'verb.communication', 'verb.cognition', 'verb.social', 'verb.social', 'verb.cogniti ...

# %%
import matplotlib.pyplot as plt
import numpy as np
labels, counts = np.unique(noun_superset1, return_counts=True)
ticks = range(len(counts))
plt.figure(figsize=(15, 8))
plt.bar(ticks, counts, align='center')
plt.xticks(ticks, range(len(counts)))
ticks = range(len(counts))

# %%
import spacy
from spacy import displacy
from collections import Counter
import en_core_web_sm
nlp = en_core_web_sm.load()
doc1 = nlp(text1)
print([[x, x.ent_iob_] for x in doc1])
# Out:
# /usr/local/lib/python3.8/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# [[start, 'O'], [project, 'O'], [gutenberg, 'O'], [ebook, 'O'], [war, 'O'], [world, 'O'], [cover, 'O'], [war, 'O'], [world, 'O'], [h, 'O'], [g, 'O'], [well, 'O'], [‘, 'O'], [shall, 'O'], [dwell, 'O'], [world, 'O'], [inhabit, 'O'], [lord, 'O'], [world, 'O'], [thing, 'O'], [made, 'O'], [man, 'O'], [kepler, 'B'], [quot, 'I'], [anatomi, 'O'], [melancholi, 'B'], [content, 'O'], [book, 'O'], [one, 'O'], [—, 'O'], [th, 'O'], [come, 'O'], [martian, 'O'], [eve, 'O'], [war, 'O'], [ii, 'O'], [fall, 'O'], [star, 'O'], [iii, 'B'], [horsel, 'I'], [common, 'O'], [iv, 'O'], [cylind, 'O'], [open, 'O'], [v, 'O'], [heatray, 'O'], [vi, 'O'], [heatray, 'O'], [chobham, 'B'], [road, 'I'], [vii, 'O'], [reach, 'O'], [home, 'O'], [viii, 'O'], [friday, 'B'], [night, 'B'], [ix, 'O'], [fight, 'O'], [begin, 'O'], [x, 'O'], [storm, 'O'], [xi, 'O'], [window, 'O'], [xii, 'O'], [saw, 'O'], [destruct, 'O'], [weybridg, 'O'], [shepperton, 'B'], [xiii, 'I'], [fell, 'O'], [curat, 'O'], [xiv, 'B'], [london, 'I'], [xv, 'B'], [happen, 'O'], [surrey, 'O'], [xvi, 'O'], [ex
'O'], [mean, 'O'], [distanc, 'O'], [140000000, 'B'], [mile, 'O'], [light, 'O'], [heat, 'O'], [receiv, 'O'], [sun, 'O'], [bare, 'O'], [half, 'B'], [receiv, 'O'], [thi, 'O'], [world, 'O'], [must, 'O'], [nebular, 'O'], [hypothesi, 'O'], [ha, 'O'], [ani, 'O'], [truth, 'O'], [older, 'O'], [world, 'O'], [long, 'O'], [befor, 'O'], [thi, 'O'], [earth, 'O'], [ceas, 'O'], [molten, 'O'], [life, 'O'], [upon, 'O'], [surfac, 'O'], [must, 'O'], [begun, 'O'], [cours, 'O'], [fact, 'O'], [scarc, 'O'], [one, 'B'], [seventh, 'O'], [volum, ...

# %%
def entity_recognition(text):
  doc=nlp(text)
  person=[]
  org=[]
  location=[]
  for X in doc:  
    if (X.ent_type_=='PERSON') and X.text not in person:
      person.append(X.text)
    if (X.ent_type_=='ORG')and X.text not in org:
      org.append(X.text)
    if ((X.ent_type_=='LOC') or (X.ent_type_=='GPE')) and X.text not in location:
      location.append(X.text)
  return person,org,location
def freq(str_list): 
    unique_words = set(str_list)
    counts = {}
    for words in unique_words : 
        counts[words] = str_list.count(words)
    return counts
person1,org1,location1=entity_recognition(text1)
print(person1)
print(org1)
print(location1)
# Out:
# ['iii', 'horsel', 'chobham', 'road', 'shepperton', 'xiii', 'xiv', 'london', 'xv', 'putney', 'hill', 'nineteenth', 'centuri', 'themselv', 'scrutinis', 'studi', 'seren', 'assur', 'mar', 'scarc', 'sinc', 'older', 'superfici', 'area', 'gather', 'melt', 'nearest', 'distanc', 'countri', 'narrow', 'schiaparelli', 'ha', 'star', 'astronom', 'exchang', 'twelv', 'compar', 'coloss', 'puff', 'flame', 'ottershaw', 'feebl', 'glow', 'activ', 'clockwork', 'kept', 'scof', 'vulgar', 'mani', 'mile', 'jubil', 'markham', 'bicycl', 'busi', 'bright', 'wife', 'berkshir', 'surrey', 'veri', 'earli', 'everi', 'direct', 'cinderi', 'henderson', 'natur', 'startl', 'amus', 'themselves', 'vaguest', 'idea', 'day', 'judg', 'mind', 'observatori', 'basketchais', 'lordli', 'carriag', 'besid', 'stent', 'hilton', 'seriou', 'impedi', 'elbow', 'jostl', 'greatli', 'caviti', 'ridg', 'absenc', 'chin', 'crippl', 'monstrou', 'toppl', 'brim', 'thick', 'cri', 'bush', 'everyth', 'confid', 'ani', 'enclos', 'pit', 'attenu', 'suddenli', 'darken', 'abruptli', 'altogeth', 'invis', 'wobbl', 'patch', 'chang', 'verg', 'safeti', 'messeng', 'hurri', 'abov', 'shriek', 'shout', 'incontin', 'alter', 'muscl', 'drunkenli', 'head', 'rose', 'arch', 'figur', 'workman', 'carri', 'basket', 'earth', 'difficulti', 'surfac', 'martian', 'albeit', 'reassur', 'ereth', 'peopl', 'routin', 'passeng', 'alight', 'londonward', 'peer', 'attitud', 'wa', 'bridg', 'certainli', 'aliv', 'milkman', 'possibl', 'crawl', 'cover', 'mysteri', 'militari', 'heard', 'chertsey', 'addleston', 'deton', 'downhil', 'landlord', 'sorri', 'best', 'express', 'inclin', 'mechan', 'aloo', 'hedg', 'ch
li', 'possibl', 'vibrat', 'ii', 'wearisom', 'apertur', 'onli', 'evid', 'convuls', 'heterogen', 'bud', 'young', 'lilybulb', 'novemb', 'decemb', 'preparatori', 'oscil', 'necessari', 'care', 'dig', 'wrestl', 'contest', 'time', 'beat', 'cajol', 'insan', 'curat', 'click', 'red', 'disord', 'imagin', 'softli', 'machineri', 'gone', 'gentl', 'day', 'putney', 'extrem', 'buri', 'franc', 'imposs', 'palac', 'glow', 'fulham', 'brompton', 'citi', 'condemn', 'derelict', 'kensington', 'marbl', 'baker', '—', 'portman', 'yelp', 'choru', 'curv', 'summit', 'invad', 'drank', 'fed', 'miracl', 'everlast', 'sun', 'blaze', 'dazzl', 'langham', 'hotel', 'dome', 'pari', 'dublin', 'edinburgh', 'manchest', 'birmingham', 'contrast', 'grotesqu', 'secret', 'flaunt', 'union', 'eastward', 'specul', 'philosophi', 'knowledg', 'compar', 'physiolog', 'confin', 'scarc', 'forthcom', 'failur', 'first', 'surpris', 'simultan']
# ['melancholi', 'london', 'vaniti', 'oblong', 'describ', 'nineti', 'buri', 'ascrib', 'henderson', 'aris', 'mayburi', 'investig', 'headlin', 'strang', 'quantiti', 'aros', 'west', 'sky', 'bridg', 'argon', 'contort', 'mosqu', 'hill', 'rang', 'heatray', 'confus', 'crest', 'fieri', 'carriag', 'blue', 'jersey', 'gravelli', 'beach', 'headlong', 'muddi', 'fulli', 'kingston', 'richmond', 'vacantli', 'tragedi', 'us', 'virginia', 'park', 'wellington', 'england', 'discourag', 'surrey', 'south', 'inclin', 'ripley', 'furi', 'disciplin', 'moscow', 'sunburi', 'injuri', 'edgwar', 'hour', 'mount', 'cycl', 'figur', 'pour', 'swiftli', 'valley', 'exactli', 'barg', 'hamburg', 'obliqu', 'inarticul', 'promptli', 'irrit', 'instantan', 'partli', 'specul', 'quasiscientif', 'feebl', 'faintli', 'slightli', 'unburi', 'grow', 'gulf', 'kensington', 'gaze', 'earnestli', 'natur', 'st', 'martinslegrand', 'shelter', 'adventur']

# %%
import spacy
from spacy import displacy
from spacy import tokenizer
from spacy.scorer import Scorer
from spacy.tokens import Doc
from spacy.training import Example

#evaluation function of the given examples
def evaluate(examples):
    scorer = Scorer()
    example = []
    nlp = spacy.load('en_core_web_sm')  # for spaCy's pretrained use 'en_core_web_sm'
    for input_, annot in examples:
        pred = nlp.make_doc(input_)
        temp = Example.from_dict(pred, annot)
        example.append(temp)
    scores = nlp.evaluate(example)
    return scores

#here we input the manually labelled data for evaluation against spaCy english NER model
examples = [('In the early 1970s, packet-switched networks began to proliferate, with the', {'entities': [(3, 18, 'DATE')]}),('ARPAnet—the precursor of the Internet—being just one of many networks. Each of',{'entities': [(0, 7, 'ORG')]}), ('these networks had its own protocol. Two researchers, Vinton Cerf and Robert Kahn,', {'entities': [(37, 40, 'CARDINAL'), (54, 65, 'PERSON'), (70, 81, 'PERSON')]}), ('network protocol called TCP/IP, which stands for Transmission Control', {'entities': [(24, 30, 'PRODUCT'), (49, 69, 'PRODUCT')]}), ('Protocol/Internet Protocol. Although Cerf and Kahn began by seeing the protocol as', {'entities': [(0, 26, 'LAW'), (46, 50, 'PERSON')]}), ('a single entity, it was later split into its two parts, TCP and IP, which operated sepa-', {'entities': [(45, 48, 'CARDINAL'), (56, 59, 'ORG'), (64, 66, 'ORG')]}), ('rately. Cerf and Kahn published a paper on TCP/IP in May 1974 in IEEE', {'entities': [(17, 21, 'PERSON'), (43, 49, 'ORG'), (53, 61, 'DATE'), (65, 69, 'ORG')]}), ('Transactions on Communications Technology [Cerf 1974].', {'entities': [(0, 41, 'ORG'), (48, 52, 'DATE')]}), ('     The TCP/IP protocol, which is the bread and butter of today’s Internet, was devised', {'entities': [(13, 15, 'ORG'), (59, 64, 'DATE')]}), ('before PCs, workstations, smartphones, and tablets, before the proliferation of Ethernet,', {'entities': [(80, 88, 'PRODUCT')]}), ('cable, and DSL, WiFi, and other access network technologies, and before the Web,', {'entities': [(11, 14, 'PRODUCT'), (16, 20, 'PRODUCT')]}), ('social media, and streaming video. Cerf and Kahn saw the need for a networking pro-', {'entities': [(44, 48, 'PERSON')]}), ('     In 2004, Cerf and Kahn received the ACM’s Turing Award, considered the', {'entities': [(8, 12, 'DATE'),(14, 18, 'PERSON'), (23, 27, 'PERSON'), (41, 44, 'ORG'), (46, 58, 'ORG')]}), ('“Nobel Prize of Computing” for “pioneering work on internetworking, including the', {'entities': [(1, 25, 'WORK_OF_ART')]}), ('design and implementation of the Internet’s basic communications protocols, TCP/IP,', {'entities': [(76, 82, 'ORG')]})]

#loading the model
nlp = spacy.load('en_core_web_sm')
t1 = open("/content/drive/MyDrive/NLP/passage1.txt", encoding="utf8").read() #read data from file
text=""
ex = []
for line in t1:
    text = line
    doc = nlp(text)
    # ents = [(e.text, e.start_char, e.end_char, e.label_) for e in doc.ents]
    temp = (line[:len(line)-1], {'entities':[(e.start_char, e.end_char, e.label_) for e in doc.ents]}) #extracting entites from the line
    if len(doc.ents)>0:
        ex.append(temp)

results = evaluate(examples)    #evaluating the model
print(ex)
print("Precision {:0.4f}\tRecall {:0.4f}\tF-score {:0.4f}".format(results['ents_p'], results['ents_r'], results['ents_f']))
# Out:
# [('', {'entities': [(0, 1, 'ORG')]}), ('', {'entities': [(0, 1, 'ORG')]}), ('', {'entities': [(0, 1, 'ORG')]}), ('', {'entities': [(0, 1, 'ORG')]}), ('', {'entities': [(0, 1, 'ORG')]}), ('', {'entities': [(0, 1, 'ORG')]}), ('', {'entities': [(0, 1, 'ORG')]}), ('', {'entities': [(0, 1, 'ORG')]}), ('', {'entities': [(0, 1, 'ORG')]}), ('', {'entities': [(0, 1, 'ORG')]}), ('', {'entities': [(0, 1, 'ORG')]}), ('', {'entities': [(0, 1, 'ORG')]}), ('', {'entities': [(0, 1, 'ORG')]}), ('', {'entities': [(0, 1, 'ORG')]}), ('', {'entities': [(0, 1, 'ORG')]}), ('', {'entities': [(0, 1, 'ORG')]})]
# Precision 0.8214	Recall 0.7667	F-score 0.7931
# /usr/local/lib/python3.8/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "     In 2004, Cerf and Kahn received the ACM’s Tur..." with entities "[(8, 12, 'DATE'), (14, 18, 'PERSON'), (23, 27, 'PE...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(

# %%
(from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
